# %%
#加载必要的库
import os
import gc
from glob import glob
from pathlib import Path
from datetime import datetime
import re

import numpy as np
import pandas as pd
import polars as pl

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
pd.set_option('display.max_columns', None)

# %%
#数据位置设置
class CFG:
    root_dir = Path("D:/home-credit-credit-risk-model-stability/")
    train_dir = Path("D:/home-credit-credit-risk-model-stability/parquet_files/train")
    test_dir = Path("D:/home-credit-credit-risk-model-stability/parquet_files/test")

# %%
if __name__ == '__main__':
    feature_definitions_df = pd.read_csv(CFG.root_dir / "feature_definitions.csv")
    display(feature_definitions_df)
    pd.reset_option("display.max_rows", 0)
# Out:
#                      Variable  \
# 0              actualdpd_943P
# 1     actualdpdtolerance_344P
# 2        addres_district_368M
# 3            addres_role_871L
# 4             addres_zip_823M
# ..                        ...
# 460  totinstallast1m_4525188A
# 461        twobodfilling_608L
# 462                  type_25L
# 463            typesuite_864L
# 464           validfrom_1069D
#
#                                            Description
# 0    Days Past Due (DPD) of previous contract (actu...
# 1                        DPD of client with tolerance.
# 2                    District of the person's address.
# 3                            Role of person's address.
# 4                             Zip code of the address.
# ..                                                 ...
# 460  Total amount of monthly instalments paid in th...
# 461                       Type of application process.
# 462                          Contact type of a person.
# ...
